# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\ebaca\\Desktop\\University of Washington\\interacting_galaxies'

# %%
from funcrefs import ViewFits as vf

# %% [markdown]
# viewing raw files, will fix aesthetics later after data reduction

# %%
folder_path = os.path.relpath("observation 1/single images")
image_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.fits')]

vf.FitsMapper(
    files = image_files,
    hdul_index = 0,
    nrows = 3,
    ncols = 3,
    figsize = (15, 15),
    cmap = 'grey',
    interpolation = 'hermite',
    interval = 'ZScale',
    stretch = 'Sqrt',
    vmin = 40,
    vmax = 96,
    animation = False
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       1 folder_path = os.path.relpath("observation 1/single images")
#       2 image_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.fits')]
# ----> 4 vf.FitsMapper(
#       5     files = image_files,
#       6     hdul_index = 0,
#       7     nrows = 3,
#       8     ncols = 3,
#       9     figsize = (15, 15),
#      10     cmap = 'grey',
#      11     interpolation = 'hermite',
#      12     interval = 'ZScale',
#      13     stretch = 'Sqrt',
#      14     vmin = 40,
#      15     vmax = 96,
#      16     animation = False
#      17 )
#
# ...
